# %% [markdown]
# System Specification

# %%
# !cat /proc/cpuinfo
# Out:
# processor	: 0
# vendor_id	: GenuineIntel
# cpu family	: 6
# model		: 79
# model name	: Intel(R) Xeon(R) CPU @ 2.20GHz
# stepping	: 0
# microcode	: 0xffffffff
# cpu MHz		: 2199.998
# cache size	: 56320 KB
# physical id	: 0
# siblings	: 2
# core id		: 0
# cpu cores	: 1
# apicid		: 0
# initial apicid	: 0
# fpu		: yes
# fpu_exception	: yes
# cpuid level	: 13
# wp		: yes
# flags		: fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ss ht syscall nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopology nonstop_tsc cpuid tsc_known_freq pni pclmulqdq ssse3 fma cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm abm 3dnowprefetch invpcid_single ssbd ibrs ibpb stibp fsgsbase tsc_adjust bmi1 hle avx2 smep bmi2 erms invpcid rtm rdseed adx smap xsaveopt arat md_clear arch_capabilities
# bugs		: cpu_meltdown spectre_v1 spectre_v2 spec_store_bypass l1tf mds swapgs taa mmio_stale_data retbleed bhi
# ...

# %%
# !cat /proc/meminfo
# Out:
# MemTotal:       13290456 kB
# MemFree:         7532776 kB
# MemAvailable:   12189468 kB
# Buffers:          384804 kB
# Cached:          4403488 kB
# SwapCached:            0 kB
# Active:           667140 kB
# Inactive:        4741624 kB
# Active(anon):       1280 kB
# Inactive(anon):   620820 kB
# Active(file):     665860 kB
# Inactive(file):  4120804 kB
# Unevictable:           8 kB
# Mlocked:               8 kB
# SwapTotal:             0 kB
# SwapFree:              0 kB
# Dirty:              3480 kB
# Writeback:             0 kB
# AnonPages:        620508 kB
# Mapped:           309012 kB
# Shmem:              1620 kB
# KReclaimable:     195596 kB
# Slab:             240064 kB
# SReclaimable:     195596 kB
# SUnreclaim:        44468 kB
# KernelStack:        5744 kB
# PageTables:        10156 kB
# SecPageTables:         0 kB
# NFS_Unstable:          0 kB
# Bounce:                0 kB
# WritebackTmp:          0 kB
# CommitLimit:     6645228 kB
# Committed_AS:    2834224 kB
# ...

# %% [markdown]
# Installing Libraries

# %%
# !pip install pandas

# %%
import pandas as pd
